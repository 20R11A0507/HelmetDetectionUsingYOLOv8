# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8

# %%
# !pip install ultralytics==8.1.34
# Out:
# ...
#   Using cached ultralytics-8.1.34-py3-none-any.whl (723 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 830.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Doing the mandatory checks of Ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# #Connecting to the Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '05 03 2022 Numaish'
# '07 01 2022 Kapra'
# '18 02 2022 Koheda'
# '2021_04_16 2_56 pm Office Lens.jpg'
# '2021_04_17 12_43 pm Office Lens.jpg'
# '20R11A0507 BEE LAB Superposition theorem.jpg'
# '20R11A0507 English Assignment - 4.gdoc'
# '20R11A0507 English assignment - 5.gdoc'
# '20R11A0507 M1 UNIT2 ASSIGNMENT.pdf'
# '20R11A0507 PPS Assignment 1.odt'
# '25 03 2024 Holi'
# '28 04 2022 Day-1'
# '29 04 2022 Day-2'
# '30 04 2022 Day-3'
# "31 12 21 Afifa's day out"
# 'Abstract MajorProject.gdoc'
#  astar.py.gdoc
#  Bike
#  CG.gdoc
#  Classroom
# 'Colab Notebooks'
# 'Debug Entity *code*.gdoc'
# 'DEBUG ENTITY.docx'
# 'DEBUG ENTITY(final.final).pptx'
#  detection-of-motorcyclists-without-helmet-main
# 'detection-of-motorcyclists-without-helmet-main (1)'
# 'Final_2_1_CSE_DS_LAB_INSTRUCTOR MANUAL_ 2021-22.gdoc'
#  ForbesAmericasTopColleges2019.csv
#  HelmetDetection
# 'Idea Presentation Format - SIH 2022.pptx'
#  Imp_Questions_2mid.doc
#  java.docx
# ...

# %% [markdown]
# #Extracting the dataset that was prepared and uploaded to the drive

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/MajorProjectNew.zip
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Archive:  /content/gdrive/MyDrive/MainDataset.zip
# replace MajorProjectNew/images/training/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: MajorProjectNew/images/training/classes.txt
#   inflating: MajorProjectNew/images/training/helmet_0.jpg
#   inflating: MajorProjectNew/images/training/helmet_0.txt
#   inflating: MajorProjectNew/images/training/helmet_1.jpg
#   inflating: MajorProjectNew/images/training/helmet_1.txt
#   inflating: MajorProjectNew/images/training/helmet_10.jpg
#   inflating: MajorProjectNew/images/training/helmet_10.txt
#   inflating: MajorProjectNew/images/training/helmet_11.jpg
#   inflating: MajorProjectNew/images/training/helmet_11.txt
#   inflating: MajorProjectNew/images/training/helmet_12.jpg
#   inflating: MajorProjectNew/images/training/helmet_12.txt
#   inflating: MajorProjectNew/images/training/helmet_13.jpg
# ...

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# Testing the pretrained model using an example

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' show=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 78.9MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 120MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 95.8ms
# Speed: 14.7ms preprocess, 95.8ms inference, 673.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data='/content/datasets/MajorProjectNew/data.yaml' epochs=100 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
